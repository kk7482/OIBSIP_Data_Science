# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Data Processing

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris=iris.drop(['Id'],axis=1)

# %%
#columns in dataset
pd.DataFrame(iris.columns)
# Out:
#                0
# 0  SepalLengthCm
# 1   SepalWidthCm
# 2  PetalLengthCm
# 3   PetalWidthCm
# 4        Species

# %%
#Central tendencies of the columns in the dataset
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#null values in the dataset
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Number and count of species
pd.DataFrame(iris["Species"].value_counts())
# Out:
#                  Species
# Iris-setosa           50
# Iris-versicolor       50
# Iris-virginica        50

# %%
#Data visualisation
sns.pairplot(iris,hue="Species")
plt.show()

# %% [markdown]
# # PROFILE REPORTING FOR BASIC OVERVIEW

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\kk748\AppData\Local\Temp\ipykernel_4664\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(iris, title = "iris_Profile_Reporting")

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-08-31 17:56:10.900981&quot;&gt;&lt;title&gt;iris_Profile_Reporting&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"])
plt.show()

# %%
plt.scatter(iris["SepalLengthCm"],iris["PetalWidthCm"])
plt.show()

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split

# %%
x= iris[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y= iris["Species"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("Accuracy: ",clf.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",clf.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0
# C:\Users\kk748\Downloads\anaconda python\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",clf.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0
